# %% [markdown]
# # Import Modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from keras.utils import np_utils
from sklearn.utils import shuffle
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pickle
import tensorflow as tf
import math as m

# %%
def plot_history(history_fine):
  f1 = history_fine.history['acc']
  val_f1 = history_fine.history['val_acc']

  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(f1, label='Acc')
  plt.plot(val_f1, label='Validation Acc')
  plt.legend(loc='lower right')
  plt.title('Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

def plot_reg_history(history_fine):
  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']
  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

# %% [markdown]
# # 1.NHẬN DẠNG KHUÔN MẶT (ANN)

# %% [markdown]
# ## 1.1 Load Data

# %%
# Load Data 
with open('Data_AI000.pickle', 'rb') as f:
    (x_train, y_train) = pickle.load(f)

# Reshape Data
x_pre = x_train[95]
x_train = x_train[:180]
y_train = y_train[:180]
x_train = x_train.reshape(x_train.shape[0], -1)

# Preprocessing Data
x_train = x_train.astype('float32')
x_train /= 255

# Encoding Y
y_train = np_utils.to_categorical(y_train, 2)

# Shuffe Data
x_train, y_train = shuffle(x_train, y_train)

# %% [markdown]
# ## 1.2 Create Model

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape = (67500,)))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer =Adam(), metrics=['acc'])

history = model.fit(x_train, y_train, batch_size = 32, epochs = 50, validation_split = 0.2)

plot_history(history)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 52ms/step - loss: 0.6577 - acc: 0.7778 - val_loss: 0.6829 - val_acc: 0.5278
# Epoch 2/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6210 - acc: 0.8611 - val_loss: 0.5280 - val_acc: 1.0000
# Epoch 3/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5075 - acc: 0.9792 - val_loss: 0.4131 - val_acc: 1.0000
# Epoch 4/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4335 - acc: 0.9861 - val_loss: 0.3551 - val_acc: 1.0000
# Epoch 5/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3646 - acc: 1.0000 - val_loss: 0.2885 - val_acc: 1.0000
# Epoch 6/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2977 - acc: 1.0000 - val_loss: 0.2244 - val_acc: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2264 - acc: 1.0000 - val_loss: 0.1615 - val_acc: 1.0000
# Epoch 8/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1562 - acc: 1.0000 - val_loss: 0.0966 - val_acc: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0896 - acc: 1.0000 - val_loss: 0.0471 - val_acc: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0417 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0172 - acc: 1.0000 - val_loss: 0.0086 - val_acc: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 14/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 8.3857e-04 - val_acc: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 13ms/step - loss: 7.9891e-04 - acc: 1.0000 - val_loss: 6.8274e-04 - val_acc: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 15ms/step - loss: 6.5920e-04 - acc: 1.0000 - val_loss: 5.8944e-04 - val_acc: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 13ms/step - loss: 5.8071e-04 - acc: 1.0000 - val_loss: 5.2808e-04 - val_acc: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 13ms/step - loss: 5.1714e-04 - acc: 1.0000 - val_loss: 4.8483e-04 - val_acc: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 14ms/step - loss: 4.7296e-04 - acc: 1.0000 - val_loss: 4.5010e-04 - val_acc: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 13ms/step - loss: 4.3808e-04 - acc: 1.0000 - val_loss: 4.2264e-04 - val_acc: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 15ms/step - loss: 4.0851e-04 - acc: 1.0000 - val_loss: 3.9917e-04 - val_acc: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 15ms/step - loss: 3.8553e-04 - acc: 1.0000 - val_loss: 3.7674e-04 - val_acc: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 14ms/step - loss: 3.6290e-04 - acc: 1.0000 - val_loss: 3.5654e-04 - val_acc: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 14ms/step - loss: 3.4292e-04 - acc: 1.0000 - val_loss: 3.3879e-04 - val_acc: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 15ms/step - loss: 3.2663e-04 - acc: 1.0000 - val_loss: 3.2228e-04 - val_acc: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 13ms/step - loss: 3.1111e-04 - acc: 1.0000 - val_loss: 3.0760e-04 - val_acc: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 13ms/step - loss: 2.9626e-04 - acc: 1.0000 - val_loss: 2.9409e-04 - val_acc: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 16ms/step - loss: 2.8312e-04 - acc: 1.0000 - val_loss: 2.8160e-04 - val_acc: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7001e-04 - acc: 1.0000 - val_loss: 2.7027e-04 - val_acc: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 13ms/step - loss: 2.5794e-04 - acc: 1.0000 - val_loss: 2.6037e-04 - val_acc: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 13ms/step - loss: 2.4749e-04 - acc: 1.0000 - val_loss: 2.5020e-04 - val_acc: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 13ms/step - loss: 2.3774e-04 - acc: 1.0000 - val_loss: 2.4048e-04 - val_acc: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 14ms/step - loss: 2.2877e-04 - acc: 1.0000 - val_loss: 2.3113e-04 - val_acc: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 15ms/step - loss: 2.1879e-04 - acc: 1.0000 - val_loss: 2.2310e-04 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1147e-04 - acc: 1.0000 - val_loss: 2.1490e-04 - val_acc: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 14ms/step - loss: 2.0312e-04 - acc: 1.0000 - val_loss: 2.0752e-04 - val_acc: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 15ms/step - loss: 1.9612e-04 - acc: 1.0000 - val_loss: 2.0020e-04 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8889e-04 - acc: 1.0000 - val_loss: 1.9360e-04 - val_acc: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.8170e-04 - acc: 1.0000 - val_loss: 1.8768e-04 - val_acc: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7581e-04 - acc: 1.0000 - val_loss: 1.8151e-04 - val_acc: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 15ms/step - loss: 1.6993e-04 - acc: 1.0000 - val_loss: 1.7525e-04 - val_acc: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6390e-04 - acc: 1.0000 - val_loss: 1.6957e-04 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5869e-04 - acc: 1.0000 - val_loss: 1.6416e-04 - val_acc: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5344e-04 - acc: 1.0000 - val_loss: 1.5929e-04 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4839e-04 - acc: 1.0000 - val_loss: 1.5494e-04 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4385e-04 - acc: 1.0000 - val_loss: 1.5077e-04 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3940e-04 - acc: 1.0000 - val_loss: 1.4647e-04 - val_acc: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3565e-04 - acc: 1.0000 - val_loss: 1.4176e-04 - val_acc: 1.0000

# %% [markdown]
# ## 1.3 Predict

# %%
# Load Test Image
plt.imshow(cv2.cvtColor(x_pre, cv2.COLOR_BGR2RGB))
print(x_pre.shape)
img = x_pre.reshape(1,-1)
img = img.astype('float32')
img /= 255
# Out:
# (150, 150, 3)

# %%
plt.title("Model dự đoán (1: Tuấn, 0: Ko phải Tuấn:) " + str(np.argmax(model.predict(img))))
plt.imshow(cv2.cvtColor(x_pre, cv2.COLOR_BGR2RGB), cmap=plt.get_cmap('gray'))

# %% [markdown]
# # 2. Nhận Dạng Khuôn Mặt (CNN)

# %% [markdown]
# ## 2.1 Load Data

# %%
# Load Data 
with open('Data_AI1.pickle', 'rb') as f:
  (x_train, y_train) = pickle.load(f)

# Reshape Data

x_pre_1 = x_train[211]
x_pre_2 = x_train[362]
x_pre_3 = x_train[451]


# Preprocessing Data
x_train = x_train.astype('float32')
x_train /= 255

# Encoding Y
y_train = np_utils.to_categorical(y_train, 4)

# Shuffe Data
x_train, y_train = shuffle(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-30-5d8afac75b12> in <module>()
#       1 # Load Data
#       2 with open('Data_AI1.pickle', 'rb') as f:
# ----> 3   (x_train, y_train) = pickle.load(f)
#       4
#       5 # Reshape Data
#
# UnpicklingError: invalid load key, '\x02'.

# %% [markdown]
# ## 2.2 Create Model

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same', input_shape = (150,150,3)))
model.add(Conv2D(32, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same'))
model.add(Conv2D(64, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same'))
model.add(Conv2D(128, (3,3), activation='relu',kernel_initializer='he_uniform', padding ='same'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 150, 150, 32)      896
#
#  conv2d_37 (Conv2D)          (None, 150, 150, 32)      9248
#
#  max_pooling2d_18 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 75, 75, 64)        18496
#
#  conv2d_39 (Conv2D)          (None, 75, 75, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 37, 37, 64)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_41 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_20 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 41472)             0
#
#  dense_12 (Dense)            (None, 128)               5308544
#
#  dense_13 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 5,596,068
# Trainable params: 5,596,068
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr = 0.001)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['acc'])
his = model.fit(x_train, y_train, epochs = 15, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 6/6 [==============================] - 3s 301ms/step - loss: 7.0358 - acc: 0.2992 - val_loss: 0.9716 - val_acc: 0.4945
# Epoch 2/15
# 6/6 [==============================] - 2s 254ms/step - loss: 0.4987 - acc: 0.8864 - val_loss: 0.0609 - val_acc: 1.0000
# Epoch 3/15
# 6/6 [==============================] - 2s 255ms/step - loss: 0.0153 - acc: 1.0000 - val_loss: 1.1568e-04 - val_acc: 1.0000
# Epoch 4/15
# 6/6 [==============================] - 2s 255ms/step - loss: 1.1765e-04 - acc: 1.0000 - val_loss: 1.3218e-06 - val_acc: 1.0000
# Epoch 5/15
# 6/6 [==============================] - 2s 255ms/step - loss: 1.5263e-06 - acc: 1.0000 - val_loss: 3.2619e-07 - val_acc: 1.0000
# Epoch 6/15
# 6/6 [==============================] - 2s 255ms/step - loss: 4.8080e-07 - acc: 1.0000 - val_loss: 1.2576e-07 - val_acc: 1.0000
# Epoch 7/15
# 6/6 [==============================] - 2s 257ms/step - loss: 3.1272e-07 - acc: 1.0000 - val_loss: 8.7769e-08 - val_acc: 1.0000
# Epoch 8/15
# 6/6 [==============================] - 1s 254ms/step - loss: 3.6852e-07 - acc: 1.0000 - val_loss: 5.2400e-08 - val_acc: 1.0000
# Epoch 9/15
# 6/6 [==============================] - 2s 256ms/step - loss: 1.6577e-07 - acc: 1.0000 - val_loss: 1.0480e-08 - val_acc: 1.0000
# Epoch 10/15
# 6/6 [==============================] - 2s 256ms/step - loss: 2.4106e-08 - acc: 1.0000 - val_loss: 5.2400e-09 - val_acc: 1.0000
# Epoch 11/15
# 6/6 [==============================] - 2s 254ms/step - loss: 9.2461e-09 - acc: 1.0000 - val_loss: 1.3100e-09 - val_acc: 1.0000
# Epoch 12/15
# 6/6 [==============================] - 2s 255ms/step - loss: 5.2835e-09 - acc: 1.0000 - val_loss: 1.3100e-09 - val_acc: 1.0000
# Epoch 13/15
# 6/6 [==============================] - 2s 255ms/step - loss: 4.6231e-09 - acc: 1.0000 - val_loss: 1.3100e-09 - val_acc: 1.0000
# Epoch 14/15
# 6/6 [==============================] - 2s 255ms/step - loss: 3.6324e-09 - acc: 1.0000 - val_loss: 1.3100e-09 - val_acc: 1.0000
# Epoch 15/15
# 6/6 [==============================] - 1s 254ms/step - loss: 3.3022e-09 - acc: 1.0000 - val_loss: 1.3100e-09 - val_acc: 1.0000

# %%
plot_history(his)

# %% [markdown]
# ## 2.3 Predict

# %%
label = ['None','Dũ', 'Tuyên', 'Tuấn']

# %%
plt.title("Đây là:  " + label[np.argmax(model.predict(x_pre_1.reshape(1,150,150,3)))])
plt.imshow(cv2.cvtColor(x_pre_1, cv2.COLOR_BGR2RGB), cmap=plt.get_cmap('gray'))

# %%
plt.title("Model dự đoán:  " + label[np.argmax(model.predict(x_pre_2.reshape(1,150,150,3)))])
plt.imshow(cv2.cvtColor(x_pre_2, cv2.COLOR_BGR2RGB), cmap=plt.get_cmap('gray'))

# %%
plt.title("Model dự đoán:  " + label[np.argmax(model.predict(x_pre_3.reshape(1,150,150,3)))])
plt.imshow(cv2.cvtColor(x_pre_3, cv2.COLOR_BGR2RGB), cmap=plt.get_cmap('gray'))
